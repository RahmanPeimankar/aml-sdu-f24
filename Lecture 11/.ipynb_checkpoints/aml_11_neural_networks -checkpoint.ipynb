# %% [markdown]
# <center><img src="img/aml-logo.png" width="600"/>
#
# ***
#
# <center>Lecture 11</center>
#
# ***
#
# <center>Neural Networks </center>
#
# ***
#
# <center>06 May 2023<center>
# <center>Rahman Peimankar<center>

# %% [markdown]
# # Agenda
#
# * Basic Architecture
# * Inside The Neural Networks
# * sklearn implementation

# %% [markdown]
# # Recap of Last Week

# %% [markdown]
# # Principal Component Analysis (PCA)

# %% [markdown]
# <div>
# <center>
# <table><tr>
# <td>
#
# <img src="img/Qimage-9-lecture10.JPG" width="300"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-28-lecture10.JPG" width="420"/>
#
# </td>
#
# <td>
#
# <img src="img/Qimage-27-lecture10.JPG" width="360"/>
#
# </td>
# </tr></table>
#
# $d_1^2 + d_2^2 + d_3^2 + d_4^2 + d_5^2 + d_6^2 =$ sum of squared distances = SS(distances)
#
# * This 1 unit long vector, consisiting of **0.97** parts Gene 1 and **0.242** parts Gene 2, is called the **Singular Vector** or the **Eigenvector** for **PC1**.
# * Also, PCA calls the SS(distances) for the best fitted line the **Eigenvalue for PC1**! And the square root of the **Eigenvalue for PC1** is called the **Singular Value for PC1**.
#
# SS(distances for PC1) = Eigenvalue for PC1
#
# $\sqrt{\text{Eigenvalue for PC1}}$ = Singular Value for PC1

# %% [markdown]
# * To draw the final PCA plot, we simply rotate everything so that PC1 is horizontal!
# * Then we use the projected points to find where the samples go in the PCA plot.
# * For example, these projected points correspond the sample 6.
#
# <table><tr>
# <td>
#
# <img src="img/Qimage-32-lecture10.JPG" width="400"/>
#
# </td>
#
#
# <td>
# <img src="img/Qimage-34-lecture10.JPG" width="350"/>
# </td>
# </tr></table>
#
# And samples 1 and 2 go here and so on.
#
# <div>
# <center>
# <table><tr>
# <td>
#
# <img src="img/Qimage-35-lecture10.JPG" width="320"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-36-lecture10.JPG" width="390"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-37-lecture10.JPG" width="390"/>
#
# </td>
# </tr></table>
#
# **This is how PCA is done using SVD.**

# %% [markdown]
# We can convert them into variation around the origin (0,0) by dividing by the sample size minus 1 (i.e. *n-1*).
#
# $\frac{\text{Eigenvalue for PC1}}{n-1}$ = Variation for PC1
#
# $\frac{\text{Eigenvalue for PC2}}{n-1}$ = Variation for PC2
#
# <div>
# <center>
# <img src="img/Qimage-40-lecture10.JPG" width="400"/>
# </div>

# %% [markdown]
# **Note**: A **Scree Plot** is a graphical representation of the percentages of variation that each PC accounts for.
#
# <div>
# <center>
# <img src="img/Qimage-41-lecture10.JPG" width="200"/>
# </div>

# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# <div>
# <center>
# <table><tr>
# <td>
#
# <img src="img/Qimage-79-lecture10.JPG" width="800"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-80-lecture10.JPG" width="800"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-81-lecture10.JPG" width="800"/>
#
# </td>
# </tr></table>

# %% [markdown]
# <div>
# <center>
# <img src="img/Qimage-82-lecture10.JPG" width="600"/>
# </div

# %% [markdown]
# <div>
# <center>
# <img src="img/Qimage-83-lecture10.JPG" width="600"/>
# </div

# %% [markdown]
# If we plot the reduction in variation per value K, there is huge reduction in variation with K=3, but after that, the variation does not go down as quickly.
#
# <div>
# <center>
# <img src="img/Qimage-84-lecture10.JPG" width="600"/>
# </div

# %% [markdown]
# # Outlier/Novelty Detection

# %% [markdown]
# <div>
# <center>
# <table><tr>
# <td>
#
# <img src="img/Qimage-86-lecture10.JPG" width="720"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-87-lecture10.JPG" width="700"/>
#
# </td>
# </tr></table>

# %% [markdown]
# # Basic idea

# %% [markdown]
# * Model data distribution p(X)
# * Outlier: p(X)<ε

# %% [markdown]
# # History
# * Nearly everything we talk about today existed ~1990
# * What changed?
#     1. More data
#     2. Faster computers (GPUs)
#     3. Some improvements:

# %% [markdown]
# # Logistic Regression as Neural Net

# %% [markdown]
# <div>
# <center>
# <img src="img/Qimage-2.JPG" width="400"/>
# </div>

# %% [markdown]
# # Basic Architecture

# %% [markdown]
# <div>
# <center>
# <img src="img/Qimage-3.JPG" width="1000"/>
# </div>

# %% [markdown]
# # Quiz
#
# In a Multilayer neural network, which of the three nodes is responsible for the calculations and has no interaction with the outside world?
#
# A) Input node
#
# B) Hidden node
#
# C) Output node

# %% [markdown]
# <div>
# <center>
# <table><tr>
# <td>
#
# **Artificial neuron**
# <img src="img/Qimage-4.png" width="630"/>
#
# </td>
# <td>
#
# **Non-linearity problem**
# <img src="img/Qimage-5.png" width="400"/>
#
# </td>
# </tr></table>
#
# <div>
# <center>

# %% [markdown]
# <center>
#
# <img src="img/Qimage-6.png" width="900"/>
# </div>

# %% [markdown]
# # Inside The Neural Networks (NNs)!

# %% [markdown]
# * Usually, people call Neural Networks a **black box** because it is hard to understand what they are doing.
# * We are going to break down each components of the **black box** and walking through how they work together.

# %% [markdown]
# Today,
#
# * we will talk about what and how NNs do things.
# * we will also talk about how NNs are fit to data with **Backpropagation**.
# * we will in addition learn about variations of NNs, including **Deep Learning**.

# %% [markdown]
# # Problem Definition

# %% [markdown]
# * Let's imagine that we have tested a drug that was designed to treat an illness.
# * We gave the drug to **3** different group of people with **3** different **Dosages**; low, medium, and high.

# %% [markdown]
# <center>
#
# <img src="img/Qimage-7.JPG" width="600"/>
# </div>

# %% [markdown]
# <center>
#
# <img src="img/Qimage-8.JPG" width="350"/>
# </div>

# %% [markdown]
# Now, we would like to predict whether ornot a future **Dosage** will be effective.

# %% [markdown]
# NNs can fit a non-linear curve to the dataset!
#
# <center>
#
# <img src="img/Qimage-9.JPG" width="400"/>
# </div>

# %% [markdown]
# Assume that we have fit the NN (<font color='green'>green <font color='black'>curve) to this dataset!

# %% [markdown]
# <center>
#
# <img src="img/Qimage-11.JPG" width="750"/>
# </div>

# %% [markdown]
# <center>
#
# <img src="img/Qimage-12.JPG" width="750"/>
# </div>

# %% [markdown]
# The first thing we are going to do is plug the lowest **Dosage, 0**, into the **Neural Network**.
#
# <center>
#
# <img src="img/Qimage-13.JPG" width="950"/>
# </div>

# %% [markdown]
# To get from the **Input Node** to the top **Node** in the **Hidden Layer**:
#    * The connection multiplies the **Dosage** by **-34.4** and then add **2.14**.
#    * The result is an x-axis coordinate for the **Activation Function**.
#
# <center>
#
# <img src="img/Qimage-14.JPG" width="700"/>
# </div>
#
# $(\text{Dosage} \times -34.4) + 2.14 = \text{x-axis coordinate}$
#
# $(0 \times -34.4) + 2.14 = 2.14$

# %% [markdown]
# $f(\text{x-axis coordinate}) = log(1 + e^{\text{x-axis coordinate}}) = \text{y-axis coordinate}$
#
# $f(\text{2.14}) = log(1 + e^{2.14}) = 2.25$

# %% [markdown]
# If we increase the **Dosage** a litle bit and put **0.1** into the input:
#
#
# <img src="img/Qimage-15.JPG" width="700"/>
#
#
# $(\text{Dosage} \times -34.4) + 2.14 = \text{x-axis coordinate}$
#
# $(0.1 \times -34.4) + 2.14 = -1.3$
#
# $f(\text{x-axis coordinate}) = log(1 + e^{\text{x-axis coordinate}}) = \text{y-axis coordinate}$
#
# $f(\text{-1.3}) = log(1 + e^{-1.3}) = 0.24$

# %% [markdown]
# <div>
# <center>
# <table><tr>
# <td>
#
# <img src="img/Qimage-16.JPG" width="300"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-17.JPG" width="305"/>
#
# </td>
# </tr></table>
#
# <div>
# <center>

# %% [markdown]
# **NOTE**: The full range of **Dosage** values, from **0** to **1**, corresponds to this relatively narrow range of values from the **Activation Function**.
#
# <center>
# <img src="img/Qimage-18.JPG" width="800"/>

# %% [markdown]
# * Now, we scale the y-axis values for the <font color='blue'>**blue curve** <font color='black'> by **-1.30**.
# * For example, when **Dosage = 0**, the current y-axis coordinate for the <font color='blue'>**blue curve** <font color='black'> is **2.25**.
# * So, we multiply **2.25** by **-1.3** and get **-2.93**.
# <center>
# <img src="img/Qimage-19.JPG" width="750"/>

# %% [markdown]
# Likewise, we multiply all of the other y-axis coordinates on the **blue curve** by **-1.3** and we end up with a NEW <font color='blue'>**blue curve** <font color='black'>.
#
# <center>
# <img src="img/Qimage-20.JPG" width="200"/>

# %% [markdown]
# * Now let's focus on the connection from the **Input Node**.
#
# <center>
# <img src="img/Qimage-21.JPG" width="800"/>
#
# $\text{x-axis coordinate} = (\text{Dosage} \times -2.52) + 1.29$
#
# $\text{x-axis coordinate} = (0 \times -2.52) + 1.29 = 1.29$
#
# $f(\text{x-axis coordinate}) = log(1 + e^{\text{x-axis coordinate}})$
#
# $f(\text{1.29}) = log(1 + e^{\text{1.29}}) = 1.53$

# %% [markdown]
# Now just plug in **Dosage** values form **0** to **1** to get the corresponding y-axis values.
#
# <center>
# <img src="img/Qimage-22.JPG" width="200"/>

# %% [markdown]
# <center>
# <img src="img/Qimage-23.JPG" width="800"/>

# %% [markdown]
# * Now the **Neural Network** tells us to add the y-axis coordinates from <font color='blue'>**blue curve** <font color='black'> to the <font color='orange'>**orange curve** <font color='black'>.
# * That gives us the <font color='green'>**green curve** <font color='black'>.
#
# <center>
# <img src="img/Qimage-24.JPG" width="800"/>

# %% [markdown]
# Finally, we subtract **0.58** from the y-axis values on the <font color='green'>**green curve** <font color='black'>.
# <center>
# <img src="img/Qimage-25.JPG" width="300"/>

# %% [markdown]
# In theory, **Neural Networks** can fit a <font color='green'>**green curve** <font color='black'> to just almost any dataset, no matter how complicated!
# <center>
# <img src="img/Qimage-26.JPG" width="1000"/>

# %% [markdown]
# # How much complexity do you think we should aim for modelling our NN?

# %% [markdown]
# <font size="25"><center>Backpropagation

# %% [markdown]
# ## Main Ideas of Backpropagation
#
# 1. Using the **Chain Rule** to calculate derivatives.
# 2. Plugging the derivatives into **Gradient Descent** to optimize parameters.

# %% [markdown]
# In the next following slides, we will talk about how the **Chain Rule** and **Gradient Descent** apply to multiple parameters simultaneously, and introduce some fancy notations!
#
# <center>
# <img src="img/Qimage-27.JPG" width="800"/>
#
# **NOTE**: **Back propagation** start with the last parameters (**$b_3$**) and works backwards to estimate all of the other parameters.

# %% [markdown]
# To start from the back, let's assume that we already have <font color='green'>optimal values<font color='black'> for all of the parameters except for the last **Bias** term (**$b_3$**).
#
# <center>
# <img src="img/Qimage-28.JPG" width="1000"/>

# %% [markdown]
# <center>
# <img src="img/Qimage-29.JPG" width="800"/>

# %% [markdown]
# <center>
# <img src="img/Qimage-30.JPG" width="800"/>
#
# * We don't know yet the optimal value for **$b_3$**, we have to give it an initial value.
# * Because **Bias** terms are usually initialized to **0**, we will set **$b_3=0$**.

# %% [markdown]
# We can quantify how good the <font color='green'>green curve<font color='black'> fits the data calculating the **Sum of the Squared Residulas**.
#
# <center>
# <img src="img/Qimage-31.JPG" width="200"/>
#
# $\text{SSR} = (0 - (-2.6))^2 + (1 - (-1.61))^2 + (0 - (-2.61))^2 = 20.4$

# %% [markdown]
# * When **$b_3 = 0$**, the **SSR = 20.4**.
# * If we increase **$b_3$** to **1**, then we would add **1** to the y-axis coordinates on the <font color='green'>**green curve** <font color='black'> and shift it up **1**.
#
# $\text{SSR} = (0 - (-1.61))^2 + (1 - (-0.61))^2 + (0 - (-1.61))^2 = 7.8$
#
# <center>
# <img src="img/Qimage-32.JPG" width="200"/>

# %% [markdown]
# If we increase $b_3$ again to **2** and **3**, we will get lower **SSR**.
#
# <div>
# <center>
# <table><tr>
# <td>
#
# <img src="img/Qimage-33.JPG" width="230"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-34.JPG" width="305"/>
#
# </td>
# </tr></table>
#
# <div>
# <center>

# %% [markdown]
# * If we had time to plug in tons of values for $b_3$, we would get this <font color='pink'>**pink curve** <font color='black'>.
# * So we could find the lowest point, which corresponds to the **$b_3$** that results in the lowest **SSR**.
# <center>
# <img src="img/Qimage-35.JPG" width="250"/>

# %% [markdown]
# * However, instead of plugging in tons of values o find the lowest point in the <font color='pink'>**pink curve** <font color='black'>, we use **Gradient Descent** to find it relatively quickly.
# <center>
# <img src="img/Qimage-36.JPG" width="220"/>
#
# * What doest that mean? (How to find the **Gradient Descent**?)

# %% [markdown]
# <center>
# <img src="img/Qimage-37.JPG" width="400"/>

# %% [markdown]
# <div>
# <center>
# <table><tr>
# <td>
#
# <img src="img/Qimage-38.JPG" width="190"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-28.JPG" width="605"/>
#
# </td>
# </tr></table>
#
# <div>
# <center>
#
#
#
# $\text{Predicted}_i$ = <font color='green'> green curve <font color='black'>= <font color='blue'> blue <font color='black'>+ <font color='orange'> orange curve <font color='black'>+ $b_3$

# %% [markdown]
# We want to use **Gradient Descent** to optimize $b_3$ and that means we need to take the derivative of the **SSR** with respect to $b_3$ ($\frac{d\,SSR}{d\,b_3}$).
#
# <center>
# <img src="img/Qimage-39.JPG" width="200"/>

# %% [markdown]
# * And because the **SSR** are linked to $b_3$ by the **Predicted** values, we can use the **Chain Rule**!
#
# $\text{SSR} = \sum_{i=1}^{n=3}(\text{Observed}_i - \text{Predicted}_i)^2$
#
# $\text{Predicted}_i$ = <font color='green'> green curve <font color='black'>= <font color='blue'> blue <font color='black'>+ <font color='orange'> orange curve <font color='black'>+ $b_3$

# %% [markdown]
# $\frac{d\,SSR}{d\,b_3} = \frac{d\,SSR}{d\,Predicted} \times \frac{d\,Predicted}{d\,b_3}$

# %% [markdown]
# 1) $\text{SSR} = \sum_{i=1}^{n=3}(\text{Observed}_i - \text{Predicted}_i)^2$
#
# 2) $\text{Predicted}_i$ = <font color='green'> green curve <font color='black'>= <font color='blue'> blue <font color='black'>+ <font color='orange'> orange curve <font color='black'>+ $b_3$
#
# 3) $\frac{d\,SSR}{d\,b_3} = \frac{d\,SSR}{d\,Predicted} \times \frac{d\,Predicted}{d\,b_3}$

# %% [markdown]
# $\frac{d\,SSR}{d\,Predicted} = \frac{d\,}{d\,Predicted} \sum_{i=1}^{n=3}(\text{Observed}_i - \text{Predicted}_i)^2 \\ \quad\quad\quad=\sum_{i=1}^{n=3}2\times(\text{Observed}_i - \text{Predicted}_i) \times \frac{d\,}{d\,Predicted}(\text{Observed - Predicted}) \\  \quad\quad\quad=\sum_{i=1}^{n=3}2\times(\text{Observed}_i - \text{Predicted}_i) \times -1 \\  \quad\quad\quad=\sum_{i=1}^{n=3}-2\times(\text{Observed}_i - \text{Predicted}_i)$

# %% [markdown]
# $\frac{d\,Predicted}{d\,b_3} = \frac{d\,}{d\,b_3} (\text{green curve}) = \frac{d\,}{d\,b_3} (\text{blue + orange} + b_3) = \frac{d\,blue}{d\,b_3} + \frac{d\,orange}{d\,b_3} + \frac{d\,b_3}{d\,b_3} = 0 + 0 + 1 = 1$

# %% [markdown]
# $\frac{d\,SSR}{d\,b_3} = \sum_{i=1}^{n=3}-2\times(\text{Observed}_i - \text{Predicted}_i) \times 1$

# %% [markdown]
# * So, we have the derivative of the **SSR** with respect to $b_3$.
#
# $\frac{d\,SSR}{d\,b_3} = \frac{d\,SSR}{d\,Predicted} \times \frac{d\,Predicted}{d\,b_3} = \sum_{i=1}^{n=3}-2\times(\text{Observed}_i - \text{Predicted}_i) \times 1$

# %% [markdown]
# * This means we can plug this derivative into **Gradient Descent** to find the optimal value for $b_3$.
#
# $\frac{d\,SSR}{d\,b_3} = -2 \times (\text{Observed}_1 - \text{Predicted}_1) \times 1\\ \quad\quad\quad + -2 \times (\text{Observed}_2 - \text{Predicted}_2) \times 1\\\quad\quad\quad + -2 \times (\text{Observed}_3 - \text{Predicted}_3) \times 1$

# %% [markdown]
# $\frac{d\,SSR}{d\,b_3} =-2 \times (0 - \text{Predicted}_1) \times 1\\ \quad\quad\quad + -2 \times (1 - \text{Predicted}_2) \times 1\\\quad\quad\quad + -2 \times (0 - \text{Predicted}_3) \times 1$

# %% [markdown]
# * How about the **Predicted** values?

# %% [markdown]
# * The values **Predicted** are given by the <font color='green'>**green curve** <font color='black'>.
# * And, we get the **predicted** values on the <font color='green'>**green curve** <font color='black'>by running the **Dosages** through the **Neural Network**.
#
# <div>
# <center>
# <table><tr>
# <td>
#
# <img src="img/Qimage-40.JPG" width="200"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-41.JPG" width="650"/>
#
# </td>
# </tr></table>
#
# <div>
# <center>
#
# $\frac{d\,SSR}{d\,b_3} =-2 \times (0 - -2.6) \times 1\\ \quad\quad\quad + -2 \times (0 - -1.6) \times 1\\\quad\quad\quad + -2 \times (0 - -2.61) \times 1 = -15.7$

# %% [markdown]
# * This corresponds to the slope for when **$b_3 = 0$**.
#
# <center>
# <img src="img/Qimage-42.JPG" width="200"/>

# %% [markdown]
# * Now we put the slope ($\frac{d\,SSR}{d\,b_3}$) into the **Gradient Descent** equation.
# * We will set the **Learning Rate** to **0.1**.
#
# **Step Size** = **Slope** $\times$ **Learning Rate** = -15.7 $\times$ 0.1 = -1.57

# %% [markdown]
# * Now we use the **Step Size** to calculate the new value for $b_3$:
#
# **New $b_3$** = **Old $b_3$** - **Step Size** = 0 - (-1.57) = 1.57

# %% [markdown]
# * Changing $b_3$ to **1.57** shifts the <font color='green'>**green curve** <font color='black'> up.
# * This shrinks the **Residuals**.
#
# <center>
# <img src="img/Qimage-43.JPG" width="700"/>

# %% [markdown]
# * Now the new **Predicted** values give us:
#
#
# <div>
#
# <table><tr>
# <td>
#
# $\frac{d\,SSR}{d\,b_3} =-2 \times (0 - (-1.03)) \times 1\\ \quad\quad\quad + -2 \times (1 - (-0.03)) \times 1\\\quad\quad\quad + -2 \times (0 - (-1.04)) \times 1 = -6.26$
#
# </td>
# <td>
#
# <img src="img/Qimage-44.JPG" width="200"/>
#
# </td>
# </tr></table>
#
# <div>
#
#
#
# * This corresponds to the slope for when **$b_3 = 1.57$**

# %% [markdown]
# **Step Size** = **Slope** $\times$ **Learning Rate** = -6.26 $\times$ 0.1 = -0.626
#
# **New $b_3$** = **Old $b_3$** - **Step Size** = **1.57** - (-0.626) = 2.19

# %% [markdown]
# * Changing **b_3** to **2.19** shifts the <font color='green'>**green curve** <font color='black'> up further.
# * That also shrinks the **Residuals** even more.
#
# <center>
# <img src="img/Qimage-45.JPG" width="200"/>

# %% [markdown]
# We just keep taking steps until the **Step Size** is close to zero.
#
# **Step Size** = **Slope** $\times$ **Learning Rate** = close to 0 $\times$ 0.1 = close to 0
#
# **New $b_3$** = **Old $b_3$** - **Step Size** = **2.61** - close to 0 = 2.61
#
# <div>
#
# <table><tr>
# <td>
#
# <img src="img/Qimage-46.JPG" width="200"/>
#
# </td>
# <td>
#
# <img src="img/Qimage-47.JPG" width="630"/>
#
# </td>
#
# <td>
#
# <img src="img/Qimage-48.JPG" width="250"/>
#
# </td>
# </tr></table>
#
# <div>

# %% [markdown]
# In conclusion, **Main Idea** for **Backpropagation** is that when a parameter like $b_3$ is unknown:
#
# * We use the **Chain Rule** to calculate the derivative of the **Sum of the Squared Residulas (SSR)**
#
#     * with respect to the unknown parameters (in this case $b_3$).
#
# * Then we initialize the unknown parameters with a number (in this case we set $b_3 = 0$)
#
# * And used **Gradient Descent** to optimize the unknown parameter

# %% [markdown]
# # Let's Get Outside The Neural Networks!

# %% [markdown]
# * Non-linear models for classification and regression
# * Work well for very large datasets
# * Slow to train – need for GPUs
# * Require preprocessing → similar to SVM or linear models, unlike trees
# * MANY variants
#     * Convolutional Neural Networks
#     * Long-Short Term Memory
#     * Generative Adverserial Networks
#     * Deep Reinforcement Learning
#     * Autoencoders

# %% [markdown]
# # Picking Optimization Algorithms

# %% [markdown]
# * **Small dataset**: off the shelf like lbfgs
# * **Big dataset**: ADAptive Moment estimation (Adam) / Root Mean Square Propagation (RMSprop)

# %% [markdown]
# Are you interested in diving deep into the neural networks optimization?
#
# Chapter 8 of Deep Learning book by Goodfellow et al. is your food!
#
# https://www.deeplearningbook.org/

# %% [markdown]
# # Neural Nets in Practice

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
np.set_printoptions(precision=3, suppress=True)
from sklearn.model_selection import train_test_split

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=100, noise=0.25, random_state=2)

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
xlim = plt.xlim()
ylim = plt.ylim()

# %%
mlp = MLPClassifier(solver='lbfgs', random_state=0).fit(X_train, y_train)
print(mlp.score(X_train, y_train))
print(mlp.score(X_test, y_test))
# Out:
# 1.0
# 0.88

# %%
xs = np.linspace(xlim[0], xlim[1], 1000)
ys = np.linspace(ylim[0], ylim[1], 1000)
xx, yy = np.meshgrid(xs, ys)
X_grid = np.c_[xx.ravel(), yy.ravel()]
plt.contour(xx, yy, mlp.predict_proba(X_grid)[:, 1].reshape(xx.shape), levels=[.5])
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)

plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-0.9671217878433745, 1.3766745187608307)

# %% [markdown]
# # Random State

# %%
import warnings
warnings.filterwarnings(action='ignore')
                        
fig, axes = plt.subplots(3, 3, figsize=(15, 10))
for ax, i in zip(axes.ravel(), range(10)):
    mlp = MLPClassifier(solver='lbfgs', random_state=i).fit(X_train, y_train)

    ax.contour(xx, yy, mlp.predict_proba(X_grid)[:, 1].reshape(xx.shape), levels=[.5])
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train)

    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    ax.set_xticks(())
    ax.set_yticks(())

# %% [markdown]
# # Hidden Layer Size

# %%
mlp = MLPClassifier(solver='lbfgs', hidden_layer_sizes=(5,), random_state=0)
mlp.fit(X_train, y_train)
print(mlp.score(X_train, y_train))
print(mlp.score(X_test, y_test))
# Out:
# 0.9733333333333334
# 0.84

# %%
plt.contour(xx, yy, mlp.predict_proba(X_grid)[:, 1].reshape(xx.shape), levels=[.5])
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)

plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-0.9671217878433745, 1.3766745187608307)

# %%
mlp = MLPClassifier(solver='lbfgs', hidden_layer_sizes=(10, 10, 10), random_state=0)
mlp.fit(X_train, y_train)
print(mlp.score(X_train, y_train))
print(mlp.score(X_test, y_test))
# Out:
# 0.9733333333333334
# 0.8

# %%
plt.contour(xx, yy, mlp.predict_proba(X_grid)[:, 1].reshape(xx.shape), levels=[.5])
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-0.9671217878433745, 1.3766745187608307)

# %% [markdown]
# # Activation Functions

# %%
mlp = MLPClassifier(solver='lbfgs', hidden_layer_sizes=(10, 10, 10), activation="tanh", random_state=0)
mlp.fit(X_train, y_train)
print(mlp.score(X_train, y_train))
print(mlp.score(X_test, y_test))
# Out:
# 1.0
# 0.92

# %%
plt.contour(xx, yy, mlp.predict_proba(X_grid)[:, 1].reshape(xx.shape), levels=[.5])
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-0.9671217878433745, 1.3766745187608307)

# %% [markdown]
# # Neural Networks for Regression

# %%
rng = np.random.RandomState(0)
x = np.sort(rng.uniform(size=100))
y = np.sin(10 * x) + 5 * x + np.random.normal(0, .3, size=100)
plt.plot(x, y, 'o')

# %%
from sklearn.neural_network import MLPRegressor
X = x.reshape(-1, 1)
mlp_relu = MLPRegressor(solver="lbfgs").fit(X, y)
mlp_tanh = MLPRegressor(solver="lbfgs", activation='tanh').fit(X, y)

# %%
line = np.linspace(0, 1, 100)
plt.plot(x, y, 'o')
plt.plot(line, mlp_relu.predict(line.reshape(-1, 1)), label="relu")
plt.plot(line, mlp_tanh.predict(line.reshape(-1, 1)), label="tanh")
plt.legend()

# %% [markdown]
# # Complexity Control

# %% [markdown]
# * Number of parameters
# * Regularization
# * Early Stopping
# * (drop-out)

# %% [markdown]
# # Grid-Searching Neural Nets

# %% [markdown]
# ### 1. Searching L2 Regularization

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, stratify=data.target, random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler
pipe = make_pipeline(StandardScaler(), MLPClassifier(solver="lbfgs", random_state=1))
param_grid = {'mlpclassifier__alpha': np.logspace(-3, 3, 7)}
grid = GridSearchCV(pipe, param_grid, cv=5, return_train_score=True)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('mlpclassifier',
#                                         MLPClassifier(random_state=1,
#                                                       solver='lbfgs'))]),
#              param_grid={'mlpclassifier__alpha': array([   0.001,    0.01 ,    0.1  ,    1.   ,   10.   ,  100.   ,
#        1000.   ])},
#              return_train_score=True)

# %%
results = pd.DataFrame(grid.cv_results_)
res = results.pivot_table(index="param_mlpclassifier__alpha", 
                          values=["mean_test_score", "mean_train_score", "std_test_score", "std_train_score"])
res
# Out:
#                             mean_test_score  mean_train_score  std_test_score  \
# param_mlpclassifier__alpha
# 0.001                              0.981231          1.000000        0.005720
# 0.010                              0.981231          1.000000        0.005720
# 0.100                              0.976553          1.000000        0.012813
# 1.000                              0.978878          0.998825        0.011516
# 10.000                             0.983611          0.990611        0.011869
# 100.000                            0.939097          0.946598        0.033973
# 1000.000                           0.626758          0.626760        0.004593
#
#                             std_train_score
# param_mlpclassifier__alpha
# 0.001                              0.000000
# 0.010                              0.000000
# 0.100                              0.000000
# 1.000                              0.001439
# 10.000                             0.002193
# 100.000                            0.002148
# 1000.000                           0.001145

# %%
res.mean_test_score.plot(yerr=res.std_test_score)
res.mean_train_score.plot(yerr=res.std_train_score)
plt.xscale("log")
plt.ylim(0.95, 1.01)
plt.legend()

# %% [markdown]
# ### 2. Searching Hidden Layer Sizes

# %%
from sklearn.model_selection import GridSearchCV
# pipe = make_pipeline(StandardScaler(), MLPClassifier(solver="lbfgs", random_state=1))

# Now it is your turn to grid search the Hidden Layer Sizes:
# You should search one and two hidden layers with sizes of (10,), (50,), (100,), (500,), (10, 10), (50, 50), (100, 100), (500, 500)
# Name the GridSearchCV object as "grid" and fit it on X_train and y_train as below:

pipe = make_pipeline(StandardScaler(), MLPClassifier(solver="lbfgs", random_state=1))

### YOUR CODE HERE
param_grid = ...

grid = GridSearchCV(pipe, param_grid, cv=5, return_train_score=True)

grid.fit(X_train, y_train)

# %%
results = pd.DataFrame(grid.cv_results_)
res = results.pivot_table(index="param_mlpclassifier__hidden_layer_sizes", 
                          values=["mean_test_score", "mean_train_score", "std_test_score", "std_train_score"])
res
# Out:
#                                          mean_test_score  mean_train_score  \
# param_mlpclassifier__hidden_layer_sizes
# (10,)                                           0.967168               1.0
# (10, 10)                                        0.957756               1.0
# (50,)                                           0.978878               1.0
# (50, 50)                                        0.974200               1.0
# (100,)                                          0.981231               1.0
# (100, 100)                                      0.974200               1.0
# (500,)                                          0.971847               1.0
# (500, 500)                                      0.976525               1.0
#
#                                          std_test_score  std_train_score
# param_mlpclassifier__hidden_layer_sizes
# (10,)                                          0.017202              0.0
# (10, 10)                                       0.005678              0.0
# (50,)                                          0.011516              0.0
# (50, 50)                                       0.015559              0.0
# (100,)                                         0.005720              0.0
# (100, 100)                                     0.008717              0.0
# (500,)                                         0.011950              0.0
# (500, 500)                                     0.007441              0.0

# %%
res.mean_test_score.plot(yerr=res.std_test_score)
res.mean_train_score.plot(yerr=res.std_train_score)
plt.legend()

# %% [markdown]
# # Introduction to Keras

# %% [markdown]
# ### 1. Preparing data

# %%
df = pd.read_csv('diabetes.csv')
print('Shape of the data frame: {}'.format(df.shape))
df.head(3)
# Out:
# Shape of the data frame: (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
X = df.iloc[:,0:8]
y = df.iloc[:, 8]
print(X.dtypes)
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### 2. Keras Sequential
#
# * It uses TensorFlow backend.
# * Install them as:
#     * ``!pip install tensorflow``
#     * ``!pip install keras``

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Input

model = Sequential([
    Dense(4, input_shape=(X_train.shape[1],), name='dense_1'),
    Activation('relu', name='activation_1'),
    Dense(1, name='dense_2'),
    Activation('sigmoid', name='activation_2')])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 4)                 36
#
#  activation_1 (Activation)   (None, 4)                 0
#
#  dense_2 (Dense)             (None, 1)                 5
#
#  activation_2 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 2. Setting Optimizer

# %% [markdown]
# <center>
# <img src="img/Qimage-49.JPG" width="1000"/>

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# https://keras.io/api/models/model_training_apis/

# %% [markdown]
# ### 3. Fit Model

# %%
history_callback = model.fit(X_train, y_train, batch_size=10, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4373 - accuracy: 0.7760
# Epoch 2/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4371 - accuracy: 0.7778
# Epoch 3/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.7778
# Epoch 4/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4372 - accuracy: 0.7778
# Epoch 5/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4367 - accuracy: 0.7795
# Epoch 6/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4366 - accuracy: 0.7743
# Epoch 7/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4363 - accuracy: 0.7778
# Epoch 8/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4361 - accuracy: 0.7778
# Epoch 9/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4364 - accuracy: 0.7760
# Epoch 10/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4360 - accuracy: 0.7743
# Epoch 11/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4357 - accuracy: 0.7760
# Epoch 12/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4358 - accuracy: 0.7760
# Epoch 13/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4357 - accuracy: 0.7760
# Epoch 14/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4355 - accuracy: 0.7778
# Epoch 15/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4354 - accuracy: 0.7778
# Epoch 16/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4353 - accuracy: 0.7760
# Epoch 17/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4353 - accuracy: 0.7743
# Epoch 18/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4354 - accuracy: 0.7760
# Epoch 19/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4351 - accuracy: 0.7743
# Epoch 20/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4350 - accuracy: 0.7778
# Epoch 21/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4347 - accuracy: 0.7778
# Epoch 22/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4351 - accuracy: 0.7743
# Epoch 23/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4347 - accuracy: 0.7726
# Epoch 24/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4350 - accuracy: 0.7708
# Epoch 25/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4348 - accuracy: 0.7726
# Epoch 26/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4344 - accuracy: 0.7760
# Epoch 27/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4346 - accuracy: 0.7743
# Epoch 28/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4341 - accuracy: 0.7726
# Epoch 29/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4343 - accuracy: 0.7743
# Epoch 30/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4341 - accuracy: 0.7743
# Epoch 31/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4341 - accuracy: 0.7743
# Epoch 32/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4342 - accuracy: 0.7760
# Epoch 33/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4341 - accuracy: 0.7726
# Epoch 34/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4336 - accuracy: 0.7760
# Epoch 35/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4337 - accuracy: 0.7743
# Epoch 36/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4334 - accuracy: 0.7743
# Epoch 37/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4337 - accuracy: 0.7743
# Epoch 38/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4335 - accuracy: 0.7778
# Epoch 39/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4339 - accuracy: 0.7795
# Epoch 40/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.7760
# Epoch 41/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4334 - accuracy: 0.7760
# Epoch 42/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4330 - accuracy: 0.7760
# Epoch 43/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.7795
# Epoch 44/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4328 - accuracy: 0.7778
# Epoch 45/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4333 - accuracy: 0.7778
# Epoch 46/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4329 - accuracy: 0.7778
# Epoch 47/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4331 - accuracy: 0.7795
# Epoch 48/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4331 - accuracy: 0.7812
# Epoch 49/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4330 - accuracy: 0.7795
# Epoch 50/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4326 - accuracy: 0.7760
# Epoch 51/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4329 - accuracy: 0.7778
# Epoch 52/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4325 - accuracy: 0.7812
# Epoch 53/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4327 - accuracy: 0.7795
# Epoch 54/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4324 - accuracy: 0.7795
# Epoch 55/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4327 - accuracy: 0.7778
# Epoch 56/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4328 - accuracy: 0.7778
# Epoch 57/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4324 - accuracy: 0.7812
# Epoch 58/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4326 - accuracy: 0.7795
# Epoch 59/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4324 - accuracy: 0.7795
# Epoch 60/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4324 - accuracy: 0.7812
# Epoch 61/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4327 - accuracy: 0.7812
# Epoch 62/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4324 - accuracy: 0.7795
# Epoch 63/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4323 - accuracy: 0.7778
# Epoch 64/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4324 - accuracy: 0.7812
# Epoch 65/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4322 - accuracy: 0.7795
# Epoch 66/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4321 - accuracy: 0.7778
# Epoch 67/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4321 - accuracy: 0.7795
# Epoch 68/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4320 - accuracy: 0.7778
# Epoch 69/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4321 - accuracy: 0.7795
# Epoch 70/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4321 - accuracy: 0.7778
# Epoch 71/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4321 - accuracy: 0.7812
# Epoch 72/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4319 - accuracy: 0.7830
# Epoch 73/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4320 - accuracy: 0.7778
# Epoch 74/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4322 - accuracy: 0.7778
# Epoch 75/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4319 - accuracy: 0.7778
# Epoch 76/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4319 - accuracy: 0.7778
# Epoch 77/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4318 - accuracy: 0.7795
# Epoch 78/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4321 - accuracy: 0.7760
# Epoch 79/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4321 - accuracy: 0.7847
# Epoch 80/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4320 - accuracy: 0.7795
# Epoch 81/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4322 - accuracy: 0.7778
# Epoch 82/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4321 - accuracy: 0.7795
# Epoch 83/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4320 - accuracy: 0.7847
# Epoch 84/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4316 - accuracy: 0.7795
# Epoch 85/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4318 - accuracy: 0.7830
# Epoch 86/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4316 - accuracy: 0.7812
# Epoch 87/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4317 - accuracy: 0.7795
# Epoch 88/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4316 - accuracy: 0.7847
# Epoch 89/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4315 - accuracy: 0.7795
# Epoch 90/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4317 - accuracy: 0.7778
# Epoch 91/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4314 - accuracy: 0.7812
# Epoch 92/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4315 - accuracy: 0.7778
# Epoch 93/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4317 - accuracy: 0.7778
# Epoch 94/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4314 - accuracy: 0.7795
# Epoch 95/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4313 - accuracy: 0.7812
# Epoch 96/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4313 - accuracy: 0.7812
# Epoch 97/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4313 - accuracy: 0.7812
# Epoch 98/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4313 - accuracy: 0.7812
# Epoch 99/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4312 - accuracy: 0.7847
# Epoch 100/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4317 - accuracy: 0.7795

# %%
pd.DataFrame(history_callback.history).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4. Evaluating on Test Set

# %%
eval_tr = model.evaluate(X_train, y_train)
eval_tr
# Out:
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4303 - accuracy: 0.7812
# [0.4302503168582916, 0.78125]

# %%
eval_ts = model.evaluate(X_test, y_test)
eval_ts
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5086 - accuracy: 0.7760
# [0.5086043477058411, 0.7760416865348816]

# %% [markdown]
# ### 5. Wrappers for sklearn

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV

def make_model(optimizer="adam", hidden_size=32):
    model = Sequential([
        Dense(4, input_shape=(X_train.shape[1],), name='dense_1'),
        Activation('relu', name='activation_1'),
        Dense(4, name='dense_2'),
        Activation('relu', name='activation_2'),
#         Dropout(0.5)
        Dense(1, name='dense_3'),
        Activation('sigmoid', name='activation_3')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

clf = KerasClassifier(make_model)
param_grid = {'epochs': [10, 50, 100],  
              'hidden_size': [(4,4), (4,16), (16,16)]}
grid = GridSearchCV(clf, param_grid=param_grid, cv=5, return_train_score=True)
grid.fit(X_train, y_train)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7084 - accuracy: 0.6543
# Epoch 2/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6985 - accuracy: 0.6565
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.6565
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6814 - accuracy: 0.6565
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6730 - accuracy: 0.6565
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6655 - accuracy: 0.6565
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6577 - accuracy: 0.6565
# Epoch 8/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6498 - accuracy: 0.6565
# Epoch 9/10
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6424 - accuracy: 0.6565
# Epoch 10/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6350 - accuracy: 0.6565
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7048 - accuracy: 0.6121
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6309 - accuracy: 0.6565
# Epoch 1/10
# 15/15 [==============================] - 1s 2ms/step - loss: 0.6802 - accuracy: 0.6312
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6724 - accuracy: 0.6594
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6649 - accuracy: 0.6768
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6580 - accuracy: 0.6963
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6508 - accuracy: 0.7007
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6437 - accuracy: 0.7028
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6364 - accuracy: 0.7050
# Epoch 8/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6290 - accuracy: 0.7050
# Epoch 9/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6218 - accuracy: 0.7158
# Epoch 10/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6143 - accuracy: 0.7180
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5907 - accuracy: 0.8261
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6103 - accuracy: 0.7223
# Epoch 1/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7698 - accuracy: 0.5944
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7558 - accuracy: 0.5922
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7443 - accuracy: 0.6247
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7329 - accuracy: 0.6291
# Epoch 5/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7215 - accuracy: 0.6377
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7109 - accuracy: 0.6356
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7007 - accuracy: 0.6334
# Epoch 8/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6901 - accuracy: 0.6356
# Epoch 9/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6804 - accuracy: 0.6312
# Epoch 10/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6708 - accuracy: 0.6312
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6711 - accuracy: 0.6435
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6662 - accuracy: 0.6334
# Epoch 1/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7216 - accuracy: 0.4685
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7068 - accuracy: 0.5011
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6936 - accuracy: 0.5488
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6819 - accuracy: 0.5965
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6711 - accuracy: 0.6377
# Epoch 6/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6615 - accuracy: 0.6529
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6525 - accuracy: 0.6486
# Epoch 8/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6438 - accuracy: 0.6486
# Epoch 9/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6356 - accuracy: 0.6486
# Epoch 10/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6271 - accuracy: 0.6486
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6331 - accuracy: 0.6435
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6226 - accuracy: 0.6486
# Epoch 1/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7485 - accuracy: 0.4382
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7221 - accuracy: 0.4751
# Epoch 3/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7013 - accuracy: 0.5184
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6859 - accuracy: 0.5401
# Epoch 5/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6731 - accuracy: 0.5597
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6632 - accuracy: 0.5987
# Epoch 7/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6550 - accuracy: 0.6139
# Epoch 8/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6479 - accuracy: 0.6291
# Epoch 9/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6418 - accuracy: 0.6377
# Epoch 10/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6357 - accuracy: 0.6443
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6481 - accuracy: 0.6174
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6320 - accuracy: 0.6529
# Epoch 1/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7613 - accuracy: 0.3239
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7464 - accuracy: 0.3304
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7335 - accuracy: 0.3522
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7224 - accuracy: 0.3978
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7131 - accuracy: 0.4500
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7055 - accuracy: 0.4935
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6988 - accuracy: 0.5500
# Epoch 8/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.5848
# Epoch 9/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6877 - accuracy: 0.6022
# Epoch 10/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6832 - accuracy: 0.6217
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.5776
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6809 - accuracy: 0.6261
# Epoch 1/10
# 15/15 [==============================] - 1s 2ms/step - loss: 0.7060 - accuracy: 0.4555
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7002 - accuracy: 0.5206
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6956 - accuracy: 0.5618
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6913 - accuracy: 0.5987
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6871 - accuracy: 0.6074
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.6182
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6795 - accuracy: 0.6334
# Epoch 8/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6751 - accuracy: 0.6421
# Epoch 9/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6712 - accuracy: 0.6486
# Epoch 10/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6668 - accuracy: 0.6464
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6525 - accuracy: 0.7130
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6644 - accuracy: 0.6486
# Epoch 1/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7495 - accuracy: 0.6529
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7312 - accuracy: 0.6529
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7150 - accuracy: 0.6616
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7013 - accuracy: 0.6486
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6876 - accuracy: 0.6529
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6735 - accuracy: 0.6638
# Epoch 7/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6601 - accuracy: 0.6659
# Epoch 8/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6468 - accuracy: 0.6681
# Epoch 9/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6330 - accuracy: 0.6768
# Epoch 10/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6201 - accuracy: 0.6920
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6362 - accuracy: 0.6087
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6129 - accuracy: 0.6963
# Epoch 1/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7023 - accuracy: 0.5119
# Epoch 2/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6915 - accuracy: 0.5380
# Epoch 3/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6817 - accuracy: 0.5965
# Epoch 4/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6727 - accuracy: 0.6312
# Epoch 5/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6639 - accuracy: 0.6855
# Epoch 6/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6551 - accuracy: 0.7007
# Epoch 7/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6461 - accuracy: 0.7223
# Epoch 8/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6371 - accuracy: 0.7267
# Epoch 9/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6283 - accuracy: 0.7354
# Epoch 10/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6189 - accuracy: 0.7332
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6197 - accuracy: 0.7217
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6142 - accuracy: 0.7310
# Epoch 1/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7131 - accuracy: 0.4989
# Epoch 2/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7001 - accuracy: 0.5423
# Epoch 3/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6888 - accuracy: 0.5813
# Epoch 4/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6800 - accuracy: 0.6161
# Epoch 5/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6731 - accuracy: 0.6377
# Epoch 6/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6665 - accuracy: 0.6551
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6609 - accuracy: 0.6659
# Epoch 8/10
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6553 - accuracy: 0.6529
# Epoch 9/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6501 - accuracy: 0.6464
# Epoch 10/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6448 - accuracy: 0.6551
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6594 - accuracy: 0.6174
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6417 - accuracy: 0.6594
# Epoch 1/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.8456 - accuracy: 0.6283
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.8153 - accuracy: 0.6283
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7868 - accuracy: 0.6087
# Epoch 4/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7666 - accuracy: 0.6152
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7458 - accuracy: 0.6174
# Epoch 6/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7299 - accuracy: 0.6174
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7142 - accuracy: 0.6152
# Epoch 8/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7018 - accuracy: 0.6152
# Epoch 9/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6893 - accuracy: 0.6196
# Epoch 10/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6787 - accuracy: 0.6283
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7548 - accuracy: 0.5862
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6733 - accuracy: 0.6348
# Epoch 1/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.8052 - accuracy: 0.4534
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7842 - accuracy: 0.4772
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7667 - accuracy: 0.5141
# Epoch 4/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7517 - accuracy: 0.5466
# Epoch 5/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7399 - accuracy: 0.5597
# Epoch 6/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7293 - accuracy: 0.5835
# Epoch 7/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7191 - accuracy: 0.5922
# Epoch 8/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7105 - accuracy: 0.6095
# Epoch 9/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7020 - accuracy: 0.6074
# Epoch 10/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6934 - accuracy: 0.6161
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7144 - accuracy: 0.6870
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6882 - accuracy: 0.6182
# Epoch 1/10
# 15/15 [==============================] - 1s 1ms/step - loss: 0.7622 - accuracy: 0.4620
# Epoch 2/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7293 - accuracy: 0.5423
# Epoch 3/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7025 - accuracy: 0.6226
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6830 - accuracy: 0.6659
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6664 - accuracy: 0.6811
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6538 - accuracy: 0.6941
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6435 - accuracy: 0.7028
# Epoch 8/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6346 - accuracy: 0.7050
# Epoch 9/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6267 - accuracy: 0.7007
# Epoch 10/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6199 - accuracy: 0.6963
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6371 - accuracy: 0.7217
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6156 - accuracy: 0.6941
# Epoch 1/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7512 - accuracy: 0.6486
# Epoch 2/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7360 - accuracy: 0.6486
# Epoch 3/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7238 - accuracy: 0.6486
# Epoch 4/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7123 - accuracy: 0.6486
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7032 - accuracy: 0.6486
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6941 - accuracy: 0.6486
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.6486
# Epoch 8/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6775 - accuracy: 0.6486
# Epoch 9/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6689 - accuracy: 0.6486
# Epoch 10/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6608 - accuracy: 0.6486
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6682 - accuracy: 0.6435
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6560 - accuracy: 0.6486
# Epoch 1/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.9623 - accuracy: 0.3905
# Epoch 2/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.8971 - accuracy: 0.4078
# Epoch 3/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.8432 - accuracy: 0.4338
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7976 - accuracy: 0.4577
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7617 - accuracy: 0.4967
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7341 - accuracy: 0.5401
# Epoch 7/10
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7129 - accuracy: 0.5835
# Epoch 8/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6955 - accuracy: 0.6052
# Epoch 9/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6818 - accuracy: 0.6269
# Epoch 10/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6699 - accuracy: 0.6486
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6910 - accuracy: 0.6261
# 15/15 [==============================] - 0s 1000us/step - loss: 0.6642 - accuracy: 0.6551
# Epoch 1/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6490 - accuracy: 0.6739
# Epoch 2/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6384 - accuracy: 0.6870
# Epoch 3/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6289 - accuracy: 0.6891
# Epoch 4/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6200 - accuracy: 0.6935
# Epoch 5/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6106 - accuracy: 0.6957
# Epoch 6/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6019 - accuracy: 0.7065
# Epoch 7/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5935 - accuracy: 0.7022
# Epoch 8/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5858 - accuracy: 0.7087
# Epoch 9/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5777 - accuracy: 0.7087
# Epoch 10/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5703 - accuracy: 0.7152
# Epoch 11/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5633 - accuracy: 0.7174
# Epoch 12/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5563 - accuracy: 0.7152
# Epoch 13/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5495 - accuracy: 0.7239
# Epoch 14/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5426 - accuracy: 0.7304
# Epoch 15/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5356 - accuracy: 0.7370
# Epoch 16/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5289 - accuracy: 0.7370
# Epoch 17/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5228 - accuracy: 0.7370
# Epoch 18/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5160 - accuracy: 0.7391
# Epoch 19/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5098 - accuracy: 0.7391
# Epoch 20/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5038 - accuracy: 0.7522
# Epoch 21/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4975 - accuracy: 0.7609
# Epoch 22/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4916 - accuracy: 0.7717
# Epoch 23/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4859 - accuracy: 0.7696
# Epoch 24/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4804 - accuracy: 0.7761
# Epoch 25/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4757 - accuracy: 0.7761
# Epoch 26/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4707 - accuracy: 0.7804
# Epoch 27/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4665 - accuracy: 0.7935
# Epoch 28/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4624 - accuracy: 0.8022
# Epoch 29/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4595 - accuracy: 0.8043
# Epoch 30/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4562 - accuracy: 0.8065
# Epoch 31/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4530 - accuracy: 0.8022
# Epoch 32/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4506 - accuracy: 0.8022
# Epoch 33/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4482 - accuracy: 0.8022
# Epoch 34/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4463 - accuracy: 0.8000
# Epoch 35/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4445 - accuracy: 0.8000
# Epoch 36/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4431 - accuracy: 0.8000
# Epoch 37/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4414 - accuracy: 0.7978
# Epoch 38/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4399 - accuracy: 0.7978
# Epoch 39/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4388 - accuracy: 0.7978
# Epoch 40/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4372 - accuracy: 0.7935
# Epoch 41/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4361 - accuracy: 0.7935
# Epoch 42/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4350 - accuracy: 0.7957
# Epoch 43/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4339 - accuracy: 0.7978
# Epoch 44/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4329 - accuracy: 0.8022
# Epoch 45/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4320 - accuracy: 0.8022
# Epoch 46/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4313 - accuracy: 0.8000
# Epoch 47/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4310 - accuracy: 0.8000
# Epoch 48/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4300 - accuracy: 0.7978
# Epoch 49/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4296 - accuracy: 0.8043
# Epoch 50/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4287 - accuracy: 0.8065
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5921 - accuracy: 0.6552
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4281 - accuracy: 0.8065
# Epoch 1/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6628 - accuracy: 0.6291
# Epoch 2/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6472 - accuracy: 0.6941
# Epoch 3/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6337 - accuracy: 0.7007
# Epoch 4/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6219 - accuracy: 0.7028
# Epoch 5/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6104 - accuracy: 0.7007
# Epoch 6/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6000 - accuracy: 0.7072
# Epoch 7/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5906 - accuracy: 0.7115
# Epoch 8/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5824 - accuracy: 0.7050
# Epoch 9/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5746 - accuracy: 0.7115
# Epoch 10/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5677 - accuracy: 0.7093
# Epoch 11/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5609 - accuracy: 0.7158
# Epoch 12/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5539 - accuracy: 0.7289
# Epoch 13/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5480 - accuracy: 0.7332
# Epoch 14/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5417 - accuracy: 0.7289
# Epoch 15/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5364 - accuracy: 0.7354
# Epoch 16/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5318 - accuracy: 0.7440
# Epoch 17/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5275 - accuracy: 0.7505
# Epoch 18/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5233 - accuracy: 0.7549
# Epoch 19/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5190 - accuracy: 0.7549
# Epoch 20/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5154 - accuracy: 0.7570
# Epoch 21/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5120 - accuracy: 0.7570
# Epoch 22/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5087 - accuracy: 0.7527
# Epoch 23/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5056 - accuracy: 0.7549
# Epoch 24/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5025 - accuracy: 0.7505
# Epoch 25/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4996 - accuracy: 0.7505
# Epoch 26/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4969 - accuracy: 0.7505
# Epoch 27/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4945 - accuracy: 0.7549
# Epoch 28/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4924 - accuracy: 0.7505
# Epoch 29/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4909 - accuracy: 0.7570
# Epoch 30/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4891 - accuracy: 0.7549
# Epoch 31/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4877 - accuracy: 0.7549
# Epoch 32/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4863 - accuracy: 0.7549
# Epoch 33/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4849 - accuracy: 0.7549
# Epoch 34/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4836 - accuracy: 0.7570
# Epoch 35/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4827 - accuracy: 0.7592
# Epoch 36/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4816 - accuracy: 0.7570
# Epoch 37/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4806 - accuracy: 0.7614
# Epoch 38/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4797 - accuracy: 0.7527
# Epoch 39/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4794 - accuracy: 0.7527
# Epoch 40/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4785 - accuracy: 0.7505
# Epoch 41/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4783 - accuracy: 0.7527
# Epoch 42/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4775 - accuracy: 0.7549
# Epoch 43/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4772 - accuracy: 0.7549
# Epoch 44/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4768 - accuracy: 0.7527
# Epoch 45/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4764 - accuracy: 0.7549
# Epoch 46/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4757 - accuracy: 0.7549
# Epoch 47/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4753 - accuracy: 0.7549
# Epoch 48/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4752 - accuracy: 0.7549
# Epoch 49/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4746 - accuracy: 0.7549
# Epoch 50/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4742 - accuracy: 0.7549
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3959 - accuracy: 0.8348
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4737 - accuracy: 0.7570
# Epoch 1/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6922 - accuracy: 0.5965
# Epoch 2/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6816 - accuracy: 0.6421
# Epoch 3/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6724 - accuracy: 0.6638
# Epoch 4/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6641 - accuracy: 0.6573
# Epoch 5/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6564 - accuracy: 0.6790
# Epoch 6/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6481 - accuracy: 0.7007
# Epoch 7/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6400 - accuracy: 0.7115
# Epoch 8/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6308 - accuracy: 0.7180
# Epoch 9/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6213 - accuracy: 0.7223
# Epoch 10/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6104 - accuracy: 0.7310
# Epoch 11/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5991 - accuracy: 0.7397
# Epoch 12/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5880 - accuracy: 0.7462
# Epoch 13/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5767 - accuracy: 0.7484
# Epoch 14/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5658 - accuracy: 0.7527
# Epoch 15/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5551 - accuracy: 0.7570
# Epoch 16/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5452 - accuracy: 0.7549
# Epoch 17/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5364 - accuracy: 0.7462
# Epoch 18/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5281 - accuracy: 0.7505
# Epoch 19/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5206 - accuracy: 0.7549
# Epoch 20/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5136 - accuracy: 0.7484
# Epoch 21/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5078 - accuracy: 0.7440
# Epoch 22/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5020 - accuracy: 0.7505
# Epoch 23/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4970 - accuracy: 0.7549
# Epoch 24/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4917 - accuracy: 0.7570
# Epoch 25/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4876 - accuracy: 0.7570
# Epoch 26/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4840 - accuracy: 0.7505
# Epoch 27/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4806 - accuracy: 0.7549
# Epoch 28/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4781 - accuracy: 0.7527
# Epoch 29/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4751 - accuracy: 0.7527
# Epoch 30/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4728 - accuracy: 0.7527
# Epoch 31/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4705 - accuracy: 0.7527
# Epoch 32/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4687 - accuracy: 0.7527
# Epoch 33/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4666 - accuracy: 0.7527
# Epoch 34/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4652 - accuracy: 0.7570
# Epoch 35/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4633 - accuracy: 0.7657
# Epoch 36/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4618 - accuracy: 0.7636
# Epoch 37/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7614
# Epoch 38/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4584 - accuracy: 0.7722
# Epoch 39/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4567 - accuracy: 0.7809
# Epoch 40/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4553 - accuracy: 0.7831
# Epoch 41/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4540 - accuracy: 0.7874
# Epoch 42/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4528 - accuracy: 0.7874
# Epoch 43/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4515 - accuracy: 0.7831
# Epoch 44/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4502 - accuracy: 0.7896
# Epoch 45/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4490 - accuracy: 0.7896
# Epoch 46/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4478 - accuracy: 0.7896
# Epoch 47/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4467 - accuracy: 0.7918
# Epoch 48/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4452 - accuracy: 0.7874
# Epoch 49/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4441 - accuracy: 0.7852
# Epoch 50/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4434 - accuracy: 0.7874
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5093 - accuracy: 0.7217
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4421 - accuracy: 0.7874
# Epoch 1/50
# 15/15 [==============================] - 1s 2ms/step - loss: 0.9615 - accuracy: 0.3492
# Epoch 2/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.9140 - accuracy: 0.3601
# Epoch 3/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.8735 - accuracy: 0.3623
# Epoch 4/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.8394 - accuracy: 0.3731
# Epoch 5/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.8115 - accuracy: 0.3861
# Epoch 6/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7861 - accuracy: 0.4035
# Epoch 7/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7656 - accuracy: 0.4338
# Epoch 8/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7469 - accuracy: 0.4664
# Epoch 9/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.7330 - accuracy: 0.4859
# Epoch 10/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.7199 - accuracy: 0.5163
# Epoch 11/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.7087 - accuracy: 0.5445
# Epoch 12/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6995 - accuracy: 0.5792
# Epoch 13/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6914 - accuracy: 0.5944
# Epoch 14/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6844 - accuracy: 0.5965
# Epoch 15/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6786 - accuracy: 0.6074
# Epoch 16/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6734 - accuracy: 0.6161
# Epoch 17/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6688 - accuracy: 0.6269
# Epoch 18/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6648 - accuracy: 0.6399
# Epoch 19/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6615 - accuracy: 0.6356
# Epoch 20/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6587 - accuracy: 0.6334
# Epoch 21/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6562 - accuracy: 0.6377
# Epoch 22/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6539 - accuracy: 0.6377
# Epoch 23/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6517 - accuracy: 0.6421
# Epoch 24/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6498 - accuracy: 0.6421
# Epoch 25/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6482 - accuracy: 0.6443
# Epoch 26/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6463 - accuracy: 0.6486
# Epoch 27/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6445 - accuracy: 0.6486
# Epoch 28/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6428 - accuracy: 0.6486
# Epoch 29/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6410 - accuracy: 0.6529
# Epoch 30/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6393 - accuracy: 0.6529
# Epoch 31/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6376 - accuracy: 0.6551
# Epoch 32/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6358 - accuracy: 0.6551
# Epoch 33/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6340 - accuracy: 0.6573
# Epoch 34/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6321 - accuracy: 0.6638
# Epoch 35/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6301 - accuracy: 0.6616
# Epoch 36/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6278 - accuracy: 0.6681
# Epoch 37/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6252 - accuracy: 0.6725
# Epoch 38/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6224 - accuracy: 0.6876
# Epoch 39/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6196 - accuracy: 0.6855
# Epoch 40/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6166 - accuracy: 0.6898
# Epoch 41/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6129 - accuracy: 0.6920
# Epoch 42/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6090 - accuracy: 0.6941
# Epoch 43/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6053 - accuracy: 0.6985
# Epoch 44/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6013 - accuracy: 0.6941
# Epoch 45/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5975 - accuracy: 0.6920
# Epoch 46/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5927 - accuracy: 0.6941
# Epoch 47/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5876 - accuracy: 0.7072
# Epoch 48/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5833 - accuracy: 0.7180
# Epoch 49/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5791 - accuracy: 0.7289
# Epoch 50/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5749 - accuracy: 0.7354
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5782 - accuracy: 0.7043
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5721 - accuracy: 0.7332
# Epoch 1/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6951 - accuracy: 0.5531
# Epoch 2/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6919 - accuracy: 0.6399
# Epoch 3/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6889 - accuracy: 0.6551
# Epoch 4/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6858 - accuracy: 0.6551
# Epoch 5/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6826 - accuracy: 0.6551
# Epoch 6/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6793 - accuracy: 0.6551
# Epoch 7/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6758 - accuracy: 0.6551
# Epoch 8/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6720 - accuracy: 0.6551
# Epoch 9/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6681 - accuracy: 0.6551
# Epoch 10/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6635 - accuracy: 0.6551
# Epoch 11/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6595 - accuracy: 0.6551
# Epoch 12/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6547 - accuracy: 0.6551
# Epoch 13/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6491 - accuracy: 0.6551
# Epoch 14/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6430 - accuracy: 0.6551
# Epoch 15/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6368 - accuracy: 0.6551
# Epoch 16/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6292 - accuracy: 0.6551
# Epoch 17/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6218 - accuracy: 0.6551
# Epoch 18/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6135 - accuracy: 0.6551
# Epoch 19/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6049 - accuracy: 0.6551
# Epoch 20/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5961 - accuracy: 0.6551
# Epoch 21/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5871 - accuracy: 0.6551
# Epoch 22/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5794 - accuracy: 0.6551
# Epoch 23/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5718 - accuracy: 0.6551
# Epoch 24/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5647 - accuracy: 0.6551
# Epoch 25/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5584 - accuracy: 0.6551
# Epoch 26/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5530 - accuracy: 0.6551
# Epoch 27/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5479 - accuracy: 0.6551
# Epoch 28/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5433 - accuracy: 0.6551
# Epoch 29/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5392 - accuracy: 0.6551
# Epoch 30/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5353 - accuracy: 0.6551
# Epoch 31/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5321 - accuracy: 0.6551
# Epoch 32/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5282 - accuracy: 0.6551
# Epoch 33/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5248 - accuracy: 0.6551
# Epoch 34/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5218 - accuracy: 0.6551
# Epoch 35/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5188 - accuracy: 0.6551
# Epoch 36/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5161 - accuracy: 0.6551
# Epoch 37/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5136 - accuracy: 0.6551
# Epoch 38/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5115 - accuracy: 0.6551
# Epoch 39/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5093 - accuracy: 0.6551
# Epoch 40/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5076 - accuracy: 0.6551
# Epoch 41/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5062 - accuracy: 0.6551
# Epoch 42/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5043 - accuracy: 0.6551
# Epoch 43/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5028 - accuracy: 0.6551
# Epoch 44/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5013 - accuracy: 0.6551
# Epoch 45/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4998 - accuracy: 0.6551
# Epoch 46/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4986 - accuracy: 0.6551
# Epoch 47/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4974 - accuracy: 0.6551
# Epoch 48/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4962 - accuracy: 0.6551
# Epoch 49/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4952 - accuracy: 0.6551
# Epoch 50/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4940 - accuracy: 0.7202
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5504 - accuracy: 0.7913
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4932 - accuracy: 0.7397
# Epoch 1/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6756 - accuracy: 0.6630
# Epoch 2/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6644 - accuracy: 0.6674
# Epoch 3/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6534 - accuracy: 0.6739
# Epoch 4/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6436 - accuracy: 0.6891
# Epoch 5/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6330 - accuracy: 0.7065
# Epoch 6/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6235 - accuracy: 0.7109
# Epoch 7/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6129 - accuracy: 0.7152
# Epoch 8/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6020 - accuracy: 0.7196
# Epoch 9/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5910 - accuracy: 0.7196
# Epoch 10/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5804 - accuracy: 0.7239
# Epoch 11/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5706 - accuracy: 0.7261
# Epoch 12/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5609 - accuracy: 0.7283
# Epoch 13/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5526 - accuracy: 0.7326
# Epoch 14/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5443 - accuracy: 0.7348
# Epoch 15/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5365 - accuracy: 0.7370
# Epoch 16/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5294 - accuracy: 0.7391
# Epoch 17/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5229 - accuracy: 0.7391
# Epoch 18/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5166 - accuracy: 0.7413
# Epoch 19/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5111 - accuracy: 0.7500
# Epoch 20/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5060 - accuracy: 0.7500
# Epoch 21/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5014 - accuracy: 0.7457
# Epoch 22/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4978 - accuracy: 0.7522
# Epoch 23/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4943 - accuracy: 0.7609
# Epoch 24/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4910 - accuracy: 0.7587
# Epoch 25/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4872 - accuracy: 0.7630
# Epoch 26/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4844 - accuracy: 0.7630
# Epoch 27/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4814 - accuracy: 0.7630
# Epoch 28/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4791 - accuracy: 0.7652
# Epoch 29/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4765 - accuracy: 0.7674
# Epoch 30/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4742 - accuracy: 0.7696
# Epoch 31/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4723 - accuracy: 0.7652
# Epoch 32/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4699 - accuracy: 0.7674
# Epoch 33/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4679 - accuracy: 0.7674
# Epoch 34/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4657 - accuracy: 0.7674
# Epoch 35/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4639 - accuracy: 0.7630
# Epoch 36/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4619 - accuracy: 0.7674
# Epoch 37/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.7674
# Epoch 38/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4585 - accuracy: 0.7717
# Epoch 39/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4568 - accuracy: 0.7717
# Epoch 40/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4552 - accuracy: 0.7739
# Epoch 41/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4541 - accuracy: 0.7761
# Epoch 42/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4528 - accuracy: 0.7717
# Epoch 43/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4512 - accuracy: 0.7739
# Epoch 44/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4500 - accuracy: 0.7783
# Epoch 45/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4489 - accuracy: 0.7826
# Epoch 46/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4480 - accuracy: 0.7870
# Epoch 47/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4466 - accuracy: 0.7826
# Epoch 48/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4457 - accuracy: 0.7826
# Epoch 49/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4443 - accuracy: 0.7870
# Epoch 50/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4432 - accuracy: 0.7891
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5965 - accuracy: 0.6466
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4422 - accuracy: 0.7913
# Epoch 1/50
# ...
# Epoch 46/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5114 - accuracy: 0.7592
# Epoch 47/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5087 - accuracy: 0.7614
# Epoch 48/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5063 - accuracy: 0.7592
# Epoch 49/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5038 - accuracy: 0.7614
# Epoch 50/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5013 - accuracy: 0.7636
# Epoch 51/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4992 - accuracy: 0.7679
# Epoch 52/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4968 - accuracy: 0.7614
# Epoch 53/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4948 - accuracy: 0.7614
# Epoch 54/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4927 - accuracy: 0.7636
# Epoch 55/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4912 - accuracy: 0.7636
# Epoch 56/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4894 - accuracy: 0.7722
# Epoch 57/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4877 - accuracy: 0.7701
# Epoch 58/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4862 - accuracy: 0.7679
# Epoch 59/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4850 - accuracy: 0.7744
# Epoch 60/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4836 - accuracy: 0.7701
# Epoch 61/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4824 - accuracy: 0.7701
# Epoch 62/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4813 - accuracy: 0.7701
# Epoch 63/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4803 - accuracy: 0.7701
# Epoch 64/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4793 - accuracy: 0.7722
# Epoch 65/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4781 - accuracy: 0.7701
# Epoch 66/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4775 - accuracy: 0.7701
# Epoch 67/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4764 - accuracy: 0.7701
# Epoch 68/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4755 - accuracy: 0.7722
# Epoch 69/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4747 - accuracy: 0.7722
# Epoch 70/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4739 - accuracy: 0.7722
# Epoch 71/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4731 - accuracy: 0.7701
# Epoch 72/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4724 - accuracy: 0.7679
# Epoch 73/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4715 - accuracy: 0.7701
# Epoch 74/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4711 - accuracy: 0.7722
# Epoch 75/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4703 - accuracy: 0.7722
# Epoch 76/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4698 - accuracy: 0.7722
# Epoch 77/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4691 - accuracy: 0.7744
# Epoch 78/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4686 - accuracy: 0.7744
# Epoch 79/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4681 - accuracy: 0.7744
# Epoch 80/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4676 - accuracy: 0.7766
# Epoch 81/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4670 - accuracy: 0.7744
# Epoch 82/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4664 - accuracy: 0.7722
# Epoch 83/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4659 - accuracy: 0.7744
# Epoch 84/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4655 - accuracy: 0.7701
# Epoch 85/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4655 - accuracy: 0.7722
# Epoch 86/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4648 - accuracy: 0.7744
# Epoch 87/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4645 - accuracy: 0.7722
# Epoch 88/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4640 - accuracy: 0.7744
# Epoch 89/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4635 - accuracy: 0.7722
# Epoch 90/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4631 - accuracy: 0.7701
# Epoch 91/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4627 - accuracy: 0.7722
# Epoch 92/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4624 - accuracy: 0.7744
# Epoch 93/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4620 - accuracy: 0.7722
# Epoch 94/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4614 - accuracy: 0.7722
# Epoch 95/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4610 - accuracy: 0.7722
# Epoch 96/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4605 - accuracy: 0.7722
# Epoch 97/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7722
# Epoch 98/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4595 - accuracy: 0.7722
# Epoch 99/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4590 - accuracy: 0.7722
# Epoch 100/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4583 - accuracy: 0.7722
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5093 - accuracy: 0.8000
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4577 - accuracy: 0.7722
# Epoch 1/100
# 18/18 [==============================] - 1s 1ms/step - loss: 0.6846 - accuracy: 0.6649
# Epoch 2/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6796 - accuracy: 0.6892
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6749 - accuracy: 0.6910
# Epoch 4/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6700 - accuracy: 0.6927
# Epoch 5/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6649 - accuracy: 0.6927
# Epoch 6/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6597 - accuracy: 0.6979
# Epoch 7/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6541 - accuracy: 0.6979
# Epoch 8/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6484 - accuracy: 0.6962
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6422 - accuracy: 0.6979
# Epoch 10/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6361 - accuracy: 0.6910
# Epoch 11/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6294 - accuracy: 0.6944
# Epoch 12/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6231 - accuracy: 0.6962
# Epoch 13/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6163 - accuracy: 0.6944
# Epoch 14/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6100 - accuracy: 0.6997
# Epoch 15/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6037 - accuracy: 0.7031
# Epoch 16/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5971 - accuracy: 0.6997
# Epoch 17/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5916 - accuracy: 0.6997
# Epoch 18/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5855 - accuracy: 0.6997
# Epoch 19/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5801 - accuracy: 0.7014
# Epoch 20/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5752 - accuracy: 0.7014
# Epoch 21/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5704 - accuracy: 0.7049
# Epoch 22/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5656 - accuracy: 0.7049
# Epoch 23/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5613 - accuracy: 0.7083
# Epoch 24/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5574 - accuracy: 0.7101
# Epoch 25/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5533 - accuracy: 0.7083
# Epoch 26/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5493 - accuracy: 0.7083
# Epoch 27/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5456 - accuracy: 0.7153
# Epoch 28/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5421 - accuracy: 0.7083
# Epoch 29/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5386 - accuracy: 0.7031
# Epoch 30/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7031
# Epoch 31/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5325 - accuracy: 0.7049
# Epoch 32/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5297 - accuracy: 0.7101
# Epoch 33/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5270 - accuracy: 0.7205
# Epoch 34/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5243 - accuracy: 0.7205
# Epoch 35/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5218 - accuracy: 0.7240
# Epoch 36/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5193 - accuracy: 0.7274
# Epoch 37/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5174 - accuracy: 0.7257
# Epoch 38/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5149 - accuracy: 0.7274
# Epoch 39/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5129 - accuracy: 0.7257
# Epoch 40/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5112 - accuracy: 0.7309
# Epoch 41/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5093 - accuracy: 0.7274
# Epoch 42/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5073 - accuracy: 0.7344
# Epoch 43/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5057 - accuracy: 0.7326
# Epoch 44/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5039 - accuracy: 0.7378
# Epoch 45/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5023 - accuracy: 0.7465
# Epoch 46/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5005 - accuracy: 0.7448
# Epoch 47/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4989 - accuracy: 0.7448
# Epoch 48/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4972 - accuracy: 0.7483
# Epoch 49/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4953 - accuracy: 0.7517
# Epoch 50/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4938 - accuracy: 0.7604
# Epoch 51/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4921 - accuracy: 0.7552
# Epoch 52/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4907 - accuracy: 0.7622
# Epoch 53/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4896 - accuracy: 0.7622
# Epoch 54/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4879 - accuracy: 0.7656
# Epoch 55/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4866 - accuracy: 0.7674
# Epoch 56/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4854 - accuracy: 0.7691
# Epoch 57/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4840 - accuracy: 0.7708
# Epoch 58/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4831 - accuracy: 0.7708
# Epoch 59/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4819 - accuracy: 0.7743
# Epoch 60/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4806 - accuracy: 0.7778
# Epoch 61/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4796 - accuracy: 0.7778
# Epoch 62/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4785 - accuracy: 0.7795
# Epoch 63/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4775 - accuracy: 0.7778
# Epoch 64/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4765 - accuracy: 0.7760
# Epoch 65/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4755 - accuracy: 0.7778
# Epoch 66/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4743 - accuracy: 0.7795
# Epoch 67/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4735 - accuracy: 0.7743
# Epoch 68/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4725 - accuracy: 0.7726
# Epoch 69/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4715 - accuracy: 0.7743
# Epoch 70/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4707 - accuracy: 0.7743
# Epoch 71/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4697 - accuracy: 0.7726
# Epoch 72/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4691 - accuracy: 0.7708
# Epoch 73/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4678 - accuracy: 0.7743
# Epoch 74/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4666 - accuracy: 0.7760
# Epoch 75/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4652 - accuracy: 0.7743
# Epoch 76/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4642 - accuracy: 0.7743
# Epoch 77/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4632 - accuracy: 0.7778
# Epoch 78/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4618 - accuracy: 0.7778
# Epoch 79/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4609 - accuracy: 0.7743
# Epoch 80/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4595 - accuracy: 0.7726
# Epoch 81/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4583 - accuracy: 0.7726
# Epoch 82/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4571 - accuracy: 0.7708
# Epoch 83/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4559 - accuracy: 0.7760
# Epoch 84/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4553 - accuracy: 0.7778
# Epoch 85/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4537 - accuracy: 0.7830
# Epoch 86/100
# 18/18 [==============================] - 0s 999us/step - loss: 0.4523 - accuracy: 0.7830
# Epoch 87/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4513 - accuracy: 0.7830
# Epoch 88/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4501 - accuracy: 0.7812
# Epoch 89/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4495 - accuracy: 0.7847
# Epoch 90/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4486 - accuracy: 0.7830
# Epoch 91/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4480 - accuracy: 0.7830
# Epoch 92/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4473 - accuracy: 0.7812
# Epoch 93/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4466 - accuracy: 0.7795
# Epoch 94/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4463 - accuracy: 0.7795
# Epoch 95/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4455 - accuracy: 0.7795
# Epoch 96/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4451 - accuracy: 0.7812
# Epoch 97/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4446 - accuracy: 0.7812
# Epoch 98/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4442 - accuracy: 0.7812
# Epoch 99/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4441 - accuracy: 0.7830
# Epoch 100/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4432 - accuracy: 0.7865
# GridSearchCV(cv=5,
#              estimator=<keras.wrappers.scikit_learn.KerasClassifier object at 0x000001A9572DF970>,
#              param_grid={'epochs': [10, 50, 100],
#                          'hidden_size': [(4, 4), (4, 16), (16, 16)]},
#              return_train_score=True)

# %%
res = pd.DataFrame(grid.cv_results_)
res.pivot_table(index=["param_epochs", "param_hidden_size"],
                values=['mean_train_score', "mean_test_score"])
# Out:
#                                 mean_test_score  mean_train_score
# param_epochs param_hidden_size
# 10           (4, 4)                    0.703058          0.686616
#              (4, 16)                   0.647376          0.651929
#              (16, 16)                  0.669940          0.658438
# 50           (4, 4)                    0.753478          0.778624
#              (4, 16)                   0.706462          0.777782
#              (16, 16)                  0.803748          0.792540
# 100          (4, 4)                    0.775967          0.798599
#              (4, 16)                   0.755157          0.798184
#              (16, 16)                  0.789850          0.802085

# %% [markdown]
# ### 6. Drop-out Regularization

# %% [markdown]
# <center>
# <img src="img/Qimage-51.JPG" width="700"/>

# %% [markdown]
# * https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf
# * Rate often as high as .5, i.e. 50% of units set to zero!
# * Avoid overfitting

# %% [markdown]
# # It Is Your Turn Now!
#
# Please implment two ``Dense`` layers in the above network.
#
# * You should add two ``Dropout`` layers after the ``Activation`` layers.
# * The dropout rate should be set as 0.5.
# * Please change the number of hidden neurons in the two ``Dense`` layers to 128 and 64, respectively.

# %%
# YOUR CODE HERE

# %% [markdown]
# <font size="25"><center>Thank you!
